# %% [markdown]
# # OWPHydroTools Demonstration
# ## Python-based Tools for Retrieving and Evaluating National Water Model Streamflow Simulations
# ### AGU Fall Meeting 2021 - Poster H450-1343
#
# *Jason A. Regina<sup>1</sup> & Arthur A. Raney<sup>2</sup>*
#
# <sup>1</sup>Office of Water Prediction, NOAA/NWS, Tuscaloosa, AL, USA
#
# <sup>2</sup>Consortium of Universities for the Advancement of Hydrologic Science, Inc., Cambridge, MA, USA (Formerly NOAA Pathways Intern, National Water Center)
#
# #### Abstract
# The OWPHydroTools suite (https://github.com/NOAA-OWP/hydrotools) includes packages used to:
#  - Asynchronously retrieve USGS streamflow observations as Pandas DataFrames
#  - Efficiently retrieve National Water Model (NWM) streamflow simulations and forecasts from Google Cloud Platform as Pandas DataFrames
#  - Generate evaluation metrics such as Nash-Sutcliffe Efficiency and Threat Score
#  - Detect hydrological events in long streamflow time series and compute single-event metrics from hydrograph features
#
# This set of python packages includes efficient algorithms suitable for use in enterprise evaluation of continental-scale hydrologic and hydraulic model outputs. We showcase the capability of these tools through an example evaluation at Little Hope Creek in Charlotte, North Carolina, USA. We demonstrate the utility of this tool set in an event-based evaluation of the NWM “open loop” simulation at Little Hope Creek that includes peak discharge error, volume error, timing errors, NNSE, and categorical statistics.
#
# <sup><sub>Presented at the AGU Fall Meeting, 13-17, Dec., 2021, New Orleans, LA
# Session H074 - Next generation water resources modeling: innovation at the intersection of domain, computer, and data sciences</sup></sub>

# %% [markdown]
# ## Introduction
#
# This example demonstrates a simple evaluation of simluated streamflow output from the National Water Model at a channel feature that corresponds to Little Hope Creek in Charlotte, NC. Specifically, it evaluates the *Extended Analysis and Assimilation No-Data Assimilation* (EANA) cycle for a 30-day period starting at 2021-06-30 12Z. This cycle is also sometimes referred as the "Open Loop" and does not includes direct replacement of simulated streamflow values with observations.
#
# The first step below just imports the necessary packages for the demonstration.

# %%
# Import National Water Model client tool
from hydrotools.nwm_client import gcp as nwm

# Import USGS NWIS IV client tool
from hydrotools.nwis_client.iv import IVDataService

# Import basic evaluation metrics
from hydrotools.metrics import metrics

# Import event detection tools
from hydrotools.events.event_detection import decomposition as ev

# Additional imports
import pandas as pd
from pathlib import Path
import dask.dataframe as dd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib widget
plt.style.use('tableau-colorblind10')

# %% [markdown]
# ## Retrieve simulations using the NWM Client Tool
#
# The current version of the `hydrotools.nwm_client` includes a `get` method that retrieves a single model cycle (forecast or simulation) as a `pandas.DataFrame`. An EANA is issued once per day at 16Z. The function below generates a list of parameters to retrieve 30 days of simulations. The function also includes steps to convert units from m<sup>3</sup>s<sup>-1</sup> to cubic feet per second. It also concatenates all the returned DataFrames into a single DataFrame. The client tool also caches these DataFrames locally to prevent repeated downloads and increase the speed of consecutive `get` requests.

# %%
# Retrieve simulations
def get_sim():
    # Set up client
    model_client = nwm.NWMDataService()

    # Generate list of references times
    reference_dts = pd.date_range(
        start="2021-07-01 16:00",
        periods=31,
        freq="24H"
    )

    # Retrieval paramteters
    configuration="analysis_assim_extend_no_da"
    reference_times = [d.strftime("%Y%m%dT%-HZ") for d in reference_dts]

    # Retrieve model data
    dfs = []
    for rt in reference_times:
        # Retrieve single simulation
        try:
            df = model_client.get(
                configuration=configuration,
                reference_time=rt
            )
        except ValueError as e:
            # Ignore missing simulation
            continue

        # Store single simluation
        dfs.append(df)

    # Concatenate simulations
    sim = pd.concat(dfs, ignore_index=True)

    # Keep "best" simulations
    sim = sim.sort_values(by=["usgs_site_code", "reference_time", "value_time"])
    sim = sim.drop_duplicates(subset=["usgs_site_code", "value_time"], keep="last")

    # Drop extra columns
    sim = sim[["usgs_site_code", "value_time", "value"]]

    # Convert to cubic feet per second
    cms_to_cfs = 0.3048 ** (-3.0)
    sim["value"] = sim["value"].mul(cms_to_cfs)

    # Drop NWIS IV incompatible locations
    mask = sim["usgs_site_code"].str.contains(r"[a-zA-Z]")
    return sim[~mask]

# %% [markdown]
# ## Use the NWIS Client Tool to retrieve observed streamflow
#
# The `get_obs` function below uses the `hydrotools.nwis_client.IVDataService.get` method to retrieve streamflow observations from the USGS NWIS Instantaneous Values API and returns them in a `pandas.DataFrame`. It's possible to use the client tool directly, but since this demonstration is a model evaluation, we've set up our `get` request to retrieve streamflow observations to match the simulations we retrieved previously. This request is quite large and may exceed the available memory of some laptops, so we employ a simple chunking and resampling strategy to reduce the size of our DataFrames.

# %%
# Retrieve observations to match simulations
def get_obs(sim):
    # Set directory to store observations
    odir = Path("observations")
    odir.mkdir(exist_ok=True)

    # Chunk USGS sites
    chunks = np.array_split(sim["usgs_site_code"].astype(str).unique(), 10)

    # Setup USGS NWIS IV client
    obs_client = IVDataService(value_time_label="value_time")

    # Retrieve observations in chunks
    for c, site_list in enumerate(chunks):
        # Check for chunk
        ofile = odir / f"part.{c}.h5"
        if ofile.exists():
            continue

        # Retrieve observations
        df = obs_client.get(
            sites=site_list,
            startDT=sim["value_time"].min(),
            endDT=sim["value_time"].max()
        )

        # Drop extra columns
        df = df[[
            'usgs_site_code', 
            'value_time', 
            'value'
            ]]

        # Check for duplicate time series, keep first by default
        df = df.drop_duplicates(
            subset=['usgs_site_code', 'value_time']
            )

        # Resample to hourly, keep first measurement in each 1-hour bin
        df = df.groupby([
            'usgs_site_code',
            pd.Grouper(key='value_time', freq='H')
            ]).first()

        # Save chunk
        df.to_hdf(ofile, key="data", format="table", complevel=1)

    # Load observations
    return dd.read_hdf("observations/*.h5", key="data").compute()

# %% [markdown]
# ## Pair simulations with observations
#
# Both the `nwm_client` and `nwis_client` tools return DataFrames in OWPHydroTools *canonical format*. This is a long format similar to a relational database and is suitable for use by other packages, such as `seaborn`. The canonical format also allows us to easily pair simulations with observations into a single DataFrame, as show below.

# %%
# Pair observations with simulations
def get_pairs():
    # Get simulations
    sim = get_sim()
    
    # Get observations
    obs = get_obs(sim)
    
    # Index simulation data
    sim = sim.set_index(["usgs_site_code", "value_time"])

    # Pair observations with simulations
    sim = sim.rename(columns={"value": "sim"})
    obs = obs.rename(columns={"value": "obs"})
    
    # Ignore negative values
    sim[sim < 0.0] = np.nan
    obs[obs < 0.0] = np.nan
    
    return pd.concat([obs, sim], axis=1)

# %% [markdown]
# ## Retrieve and pair data
# The functions shown above retrieve and pair NWM simulations with USGS streamflow observations. The final step in this process is to actually call the functions. The first time you run this process, it will take some time depending on your bandwidth and local compute resources.

# %%
# Retrieve and pair data
pairs = get_pairs()

# Sort multi-index to avoid performance warnings
pairs = pairs.reset_index().sort_values(by=["usgs_site_code", "value_time"])
pairs = pairs.set_index(["usgs_site_code", "value_time"])
pairs.head().style.format("{:.2f}")
# Out:
# <style type="text/css">
# </style>
# <table id="T_d9f74">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d9f74_level0_col0" class="col_heading level0 col0" >obs</th>
#       <th id="T_d9f74_level0_col1" class="col_heading level0 col1" >sim</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >usgs_site_code</th>
#       <th class="index_name level1" >value_time</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d9f74_level0_row0" class="row_heading level0 row0" rowspan="5">01010000</th>
#       <th id="T_d9f74_level1_row0" class="row_heading level1 row0" >2021-06-30 13:00:00</th>
#       <td id="T_d9f74_row0_col0" class="data row0 col0" >1230.00</td>
#       <td id="T_d9f74_row0_col1" class="data row0 col1" >344.67</td>
#     </tr>
#     <tr>
#       <th id="T_d9f74_level1_row1" class="row_heading level1 row1" >2021-06-30 14:00:00</th>
#       <td id="T_d9f74_row1_col0" class="data row1 col0" >1210.00</td>
#       <td id="T_d9f74_row1_col1" class="data row1 col1" >352.44</td>
#     </tr>
#     <tr>
#       <th id="T_d9f74_level1_row2" class="row_heading level1 row2" >2021-06-30 15:00:00</th>
#       <td id="T_d9f74_row2_col0" class="data row2 col0" >1180.00</td>
#       <td id="T_d9f74_row2_col1" class="data row2 col1" >357.74</td>
#     </tr>
#     <tr>
#       <th id="T_d9f74_level1_row3" class="row_heading level1 row3" >2021-06-30 16:00:00</th>
#       <td id="T_d9f74_row3_col0" class="data row3 col0" >1170.00</td>
#       <td id="T_d9f74_row3_col1" class="data row3 col1" >364.45</td>
#     </tr>
#     <tr>
#       <th id="T_d9f74_level1_row4" class="row_heading level1 row4" >2021-06-30 17:00:00</th>
#       <td id="T_d9f74_row4_col0" class="data row4 col0" >1150.00</td>
#       <td id="T_d9f74_row4_col1" class="data row4 col1" >371.16</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Evaluate
#
# The next steps focus on evaluating the performance of the NWM simulation at a single site (Little Hope Creek, USGS Site: 02146470). The following steps demonstrate how to use OWPHydroTools to generate a contingency table, categorical statistics, and event-based metrics.

# %%
# Work with a subset of data
#  Forward fill missing data
df = pairs.loc[("02146470",),:].ffill()

# %%
# Plot
fig, ax = plt.subplots()
df.plot(ax=ax, logy=True)
ax.set_title("NWM Extended ANA (No-DA)\nUSGS site: 02146470, Little Hope Cr, NC")
ax.set_xlabel("Datetime (UTC)")
ax.set_ylabel(r"Streamflow ($feet^3 s^{-1}$) [log]")
ax.legend(["USGS", "NWM"])
fig.tight_layout()
plt.show(fig)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Categorical Evaluation
#
# Categorical evalutions require dichotmous criteria to transform single-valued time series into categories. For this demonstration, our criterion was a maximum daily streamflow equal to or greater than 10.0 cubic feet per second. Using this criterion, we can construct a contingency table as shown below.

# %%
# Daily maximum flows
daily_max = df.resample("1D").max()

# Apply flow exceedance criteria to forecasts (10.0 CFS)
criteria = 10.0
daily_max['simulated_flow_ex'] = (daily_max['sim'] >= criteria)
daily_max['observed_flow_ex'] = (daily_max['obs'] >= criteria)

# Convert boolean columns to Categoricals
daily_max['simulated_flow_ex'] = daily_max['simulated_flow_ex'].astype('category')
daily_max['observed_flow_ex'] = daily_max['observed_flow_ex'].astype('category')

# Compute contingency table
contingency_table = metrics.compute_contingency_table(
    daily_max['observed_flow_ex'],
    daily_max['simulated_flow_ex']
)

# %%
# Print pretty version of continengency table
pretty_ct = contingency_table.to_frame(name="Count")
pretty_ct.index.name = "Contingency Table"
pretty_ct = pretty_ct.rename(index={
    "true_positive": "True Positives",
    "false_positive": "False Positives",
    "false_negative": "False Negatives",
    "true_negative": "True Negatives",
})
pretty_ct
# Out:
#                    Count
# Contingency Table
# True Positives         7
# False Positives        2
# False Negatives        2
# True Negatives        21

# %% [markdown]
# ### Categorical Metrics
#
# Once we have a contingency table, we can derive statistics. Below we compute a variety of cateorical statistics using the contingency table generated above. The `hydrotools.metrics` package also has additional non-categorical metrics, such as *Nash-Sutcliffe Efficiency* (NSE). Below, we compute the *Normalized* NSE.

# %%
# Compute suite of categorical verification metrics
metrics_suite = pd.DataFrame.from_dict({
    "POD": metrics.probability_of_detection(contingency_table),
    "POFD": metrics.probability_of_false_detection(contingency_table),
    "POFA": metrics.probability_of_false_alarm(contingency_table),
    "FBI": metrics.frequency_bias(contingency_table),
    "CSI": metrics.threat_score(contingency_table),
    "ETS": metrics.equitable_threat_score(contingency_table),
    "NNSE": metrics.nash_sutcliffe_efficiency(df["obs"], df["sim"], normalized=True)
}, orient="index", columns=["Value"])
metrics_suite.index.name = "Metric"
metrics_suite.style.format('{:.3f}')
# Out:
# <style type="text/css">
# </style>
# <table id="T_b571e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b571e_level0_col0" class="col_heading level0 col0" >Value</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Metric</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b571e_level0_row0" class="row_heading level0 row0" >POD</th>
#       <td id="T_b571e_row0_col0" class="data row0 col0" >0.778</td>
#     </tr>
#     <tr>
#       <th id="T_b571e_level0_row1" class="row_heading level0 row1" >POFD</th>
#       <td id="T_b571e_row1_col0" class="data row1 col0" >0.087</td>
#     </tr>
#     <tr>
#       <th id="T_b571e_level0_row2" class="row_heading level0 row2" >POFA</th>
#       <td id="T_b571e_row2_col0" class="data row2 col0" >0.222</td>
#     </tr>
#     <tr>
#       <th id="T_b571e_level0_row3" class="row_heading level0 row3" >FBI</th>
#       <td id="T_b571e_row3_col0" class="data row3 col0" >1.000</td>
#     </tr>
#     <tr>
#       <th id="T_b571e_level0_row4" class="row_heading level0 row4" >CSI</th>
#       <td id="T_b571e_row4_col0" class="data row4 col0" >0.636</td>
#     </tr>
#     <tr>
#       <th id="T_b571e_level0_row5" class="row_heading level0 row5" >ETS</th>
#       <td id="T_b571e_row5_col0" class="data row5 col0" >0.528</td>
#     </tr>
#     <tr>
#       <th id="T_b571e_level0_row6" class="row_heading level0 row6" >NNSE</th>
#       <td id="T_b571e_row6_col0" class="data row6 col0" >0.268</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Event-based Evaluation
#
# This evaluation uses `hydrotools.events` to partition streamflow into discrete "events". In this case, the event detection algorithm we use has been shown to perform well on flashy rainfall-driven runoff events (common in North Carolina). We run the algorithm on both simulated and observed streamflow and compute event-based quantities like peak streamflow, time of peak, and total volume. By comparing time coincident events, we can compute event-based metrics like peak error, peak timing error, and volume error.

# %%
# Mark observed "event" flow
df["obs_ev"] = ev.mark_event_flows(df["obs"], halflife='12H', window='7D', start_radius='12H',
    minimum_event_duration='1D')
df.loc[df["obs_ev"], "ev_flow"] = df.loc[df["obs_ev"], "obs"]
df.loc[~df["obs_ev"], "nev_flow"] = df.loc[~df["obs_ev"], "obs"]

# %%
# Plot observed events
fig, ax = plt.subplots()
df[["ev_flow", "nev_flow"]].plot(ax=ax, logy=True)
ax.set_title("Observed Events\nUSGS site: 02146470, Little Hope Cr, NC")
ax.set_xlabel("Datetime (UTC)")
ax.set_ylabel(r"Streamflow ($feet^3 s^{-1}$) [log]")
ax.legend(["Event", "Non-event"])
fig.tight_layout()
plt.show(fig)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Characterize event flows
def characterize_events(events, values):
    # Event duration
    events["duration"] = events["end"].sub(events["start"])
    
    # Compute peak flows in cubic feet per second
    events['peak'] = events.apply(
        lambda e: values.loc[e.start:e.end].max(),
        axis=1
        )
    
    # Find time of peak
    events['time_of_peak'] = events.apply(
        lambda e: values.loc[e.start:e.end].idxmax(),
        axis=1
        )
    
    # Compute total volume in ac-ft
    #  Assumes hourly discharge values in cubic feet per second
    #  Conversion: (3600 seconds per hour) * (1 acre per 43,560 square feet)
    #  Reduced conversion factor: 10/121
    events['volume'] = events.apply(
        lambda e: values.loc[e.start:e.end].sum() * (10.0/121.0),
        axis=1
        )
    return events

# %%
# Detect observed events
#  This particular algorithm is suited for flashy rainfall-driven runoff "events"
obs_events = ev.list_events(df["obs"], halflife='12H', window='7D', start_radius='12H',
    minimum_event_duration='1D')
obs_events = characterize_events(obs_events, df["obs"])

# Drop first event (erroneous baseflow in obs)
# obs_events = obs_events.iloc[1:]
obs_events
# Out:
#                 start                 end        duration        peak  \
# 0 2021-07-01 23:00:00 2021-07-04 01:00:00 2 days 02:00:00   48.299999
# 1 2021-07-08 01:00:00 2021-07-11 17:00:00 3 days 16:00:00  148.000000
# 2 2021-07-12 11:00:00 2021-07-14 17:00:00 2 days 06:00:00  120.000000
# 3 2021-07-18 23:00:00 2021-07-22 03:00:00 3 days 04:00:00  153.000000
# 4 2021-07-26 10:00:00 2021-07-29 00:00:00 2 days 14:00:00   78.599998
#
#          time_of_peak     volume
# 0 2021-07-02 02:00:00  17.229753
# 1 2021-07-09 20:00:00  28.260329
# 2 2021-07-12 23:00:00  17.245456
# 3 2021-07-19 17:00:00  44.263639
# 4 2021-07-26 23:00:00  25.497525

# %%
# Detect simulated events
sim_events = ev.list_events(df["sim"], halflife='12H', window='7D', start_radius='12H',
    minimum_event_duration='1D')
sim_events = characterize_events(sim_events, df["sim"])
sim_events
# Out:
#                 start                 end        duration        peak  \
# 0 2021-07-01 14:00:00 2021-07-03 10:00:00 1 days 20:00:00  107.356583
# 1 2021-07-09 07:00:00 2021-07-11 13:00:00 2 days 06:00:00  250.380981
# 2 2021-07-19 01:00:00 2021-07-21 07:00:00 2 days 06:00:00   94.290154
# 3 2021-07-26 12:00:00 2021-07-28 21:00:00 2 days 09:00:00  349.968353
#
#          time_of_peak      volume
# 0 2021-07-02 01:00:00   42.669456
# 1 2021-07-09 19:00:00   79.822821
# 2 2021-07-19 06:00:00   64.558716
# 3 2021-07-26 22:00:00  113.707386

# %%
# Evaluate simulated events
error_metrics = pd.DataFrame()
error_metrics.index.name = "Event ID"
for e in sim_events.itertuples():
    # Find matching observed event
    matching_event = obs_events.loc[obs_events["start"] <= e.end, :]
    matching_event = matching_event.loc[matching_event["end"] >= e.start, :]
    
    # Check for no event
    if matching_event.empty:
        continue
    
    # Extract observed values
    obs_pk = matching_event["peak"].iloc[0]
    obs_pk_tm = matching_event["time_of_peak"].iloc[0]
    obs_vol = matching_event["volume"].iloc[0]
    
    # Compute errors
    peak_error = 100 * (e.peak - obs_pk) / obs_pk
    peak_time_error = (e.time_of_peak - obs_pk_tm) / pd.Timedelta("1H")
    volume_error = 100 * (e.volume - obs_vol) / obs_vol
    
    # Add to dataframe
    error_metrics.loc[e.Index, "Peak Discharge Error (%)"] = peak_error
    error_metrics.loc[e.Index, "Time of Peak Error (hours)"] = peak_time_error
    error_metrics.loc[e.Index, "Volumetric Discharge Error (%)"] = volume_error
error_metrics.style.format("{:.2f}")
# Out:
# <style type="text/css">
# </style>
# <table id="T_5085f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5085f_level0_col0" class="col_heading level0 col0" >Peak Discharge Error (%)</th>
#       <th id="T_5085f_level0_col1" class="col_heading level0 col1" >Time of Peak Error (hours)</th>
#       <th id="T_5085f_level0_col2" class="col_heading level0 col2" >Volumetric Discharge Error (%)</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Event ID</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5085f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5085f_row0_col0" class="data row0 col0" >122.27</td>
#       <td id="T_5085f_row0_col1" class="data row0 col1" >-1.00</td>
#       <td id="T_5085f_row0_col2" class="data row0 col2" >147.65</td>
#     </tr>
#     <tr>
#       <th id="T_5085f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_5085f_row1_col0" class="data row1 col0" >69.18</td>
#       <td id="T_5085f_row1_col1" class="data row1 col1" >-1.00</td>
#       <td id="T_5085f_row1_col2" class="data row1 col2" >182.46</td>
#     </tr>
#     <tr>
#       <th id="T_5085f_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_5085f_row2_col0" class="data row2 col0" >-38.37</td>
#       <td id="T_5085f_row2_col1" class="data row2 col1" >-11.00</td>
#       <td id="T_5085f_row2_col2" class="data row2 col2" >45.85</td>
#     </tr>
#     <tr>
#       <th id="T_5085f_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_5085f_row3_col0" class="data row3 col0" >345.25</td>
#       <td id="T_5085f_row3_col1" class="data row3 col1" >-1.00</td>
#       <td id="T_5085f_row3_col2" class="data row3 col2" >345.95</td>
#     </tr>
#   </tbody>
# </table>
